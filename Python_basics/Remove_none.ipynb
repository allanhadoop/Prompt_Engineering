# %%
from sympy.codegen.ast import none
args = {
    "name"  : "jim", 
    "place" : "india",
    "geo" : "asia" ,
    "currency" : "INR" }

filtered_arg = { k : v for k, v in args.items() if v != "asia"}
print(filtered_arg)
# Out:
# {'name': 'jim', 'place': 'india', 'currency': 'INR'}
