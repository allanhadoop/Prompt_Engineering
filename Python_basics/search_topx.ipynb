# %%
# Search through a list of documents, find the closest matches to my query, and return the top 3.
from unittest import result

documents = [
    "cancer treatment",
    "cancer research",
    "diabetes treatment",
    "lung cancer"
]
query = 'cancer'
def levenshtein_search(
    query: str,
    documents: list[str],
    top_k: int = 3                          # Give me the 3 closest matches.
) -> list[tuple[int, float, str]]:          # the function returns a list of results, where each result contains 3 things: int, float, str. For example
                                            #  (0, 0.95, "cancer treatment") - This is tuple - 3 values belong together as one result.
    result = []
    score = 1
    index = 2 
    result.append((index,score, documents[1]))
    return result 

result = levenshtein_search(query, documents)
print(result)
# Out:
# [(2, 1, 'cancer research')]
