# %%
# Text → Embedding/vector → Chroma vector database → Search
"""
-----------Track 1 --------Without LangChain----- 
    Python
    ↓
    Sentence Transformers
    ↓
    all-MiniLM-L6-v2
    ↓
    vectors
    ↓
    Chroma directly
-----------Track 2-----------With LangChain----
    Python
    ↓
    LangChain
    ↓
    HuggingFace Embeddings → MiniLM → vectors
    ↓
    LangChain Chroma → Chroma database
"""
