# %%
# Vector respresentations for semantic search and similarity 

from openai import openai
client = openai()

response = client.embeddings.create(
    input = "I love cat and dog",
    model = "text-embedding-3-small"               # This is not a auto-regressive LLM, this is embedding model
)
print(response.data[0].embedding)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Vector respresentations for semantic search and similarity
# ----> 3 from openai import openai
#       4 client = openai()
#       6 response = client.embeddings.create(
#       7     input = "I love cat and dog",
#       8     model = "text-embedding-3-small"               # This is not a auto-regressive LLM, this is embedding model
#       9 )
#
# ImportError: cannot import name 'openai' from 'openai' (c:\Users\allan\projects\llm_engineering\.venv\Lib\site-packages\openai\__init__.py)
