# %%
from openai import openai
client = openai()

response = client.responses.create(
            model = "gpt-5.2",
            input = "Write a one sentence phase for insipration"
)

print(response.output_text)
